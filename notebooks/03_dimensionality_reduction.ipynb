# %% [markdown]
# # Dimensionality Reduction
#
# Applies PCA and t-SNE to the five sub-scores to visualise county structure in 2D.
# t-SNE coordinates are persisted for use in the clustering stage.
#
# **Input:** `data/processed/features.csv`
# **Output:** `figs/pca.png`, `figs/tsne.png`, `data/processed/tsne_coords.npy`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import os
# Out:
# C:\Users\Josh\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.4' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\Josh\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
processed_data_path = "../data/processed/"
fig_dir = "../figs/"
os.makedirs(fig_dir, exist_ok=True)

df = pd.read_csv(f"{processed_data_path}features.csv")
score_cols = ["health_score", "air_quality_score", "economic_score", "traffic_score", "crime_score"]

standard_scale = StandardScaler()
X_scaled = standard_scale.fit_transform(df[score_cols])

def add_watermark(fig):
    fig.text(0.99, 0.01, '© Joshua Osborne', ha='right', va='bottom',
             fontsize=7, color='gray', alpha=0.6, transform=fig.transFigure)

# %%
pca = PCA(n_components=2)
pca.fit(X_scaled)
print("Explained variance ratio:", pca.explained_variance_ratio_)
print("PCA loadings:\n", pca.components_)

fig = plt.figure()
plt.title('PCA Loadings')
plt.scatter(*pca.components_)
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
add_watermark(fig)
plt.savefig(f'{fig_dir}pca.png')
plt.close()
print("PCA plot saved.")

# %%
tsne = TSNE(n_components=2, random_state=42, perplexity=30)
tsne_coords = tsne.fit_transform(X_scaled)

fig = plt.figure()
plt.scatter(tsne_coords[:, 0], tsne_coords[:, 1], c=df['safety_score'], cmap='RdYlGn')
plt.colorbar(label='safety_score')
plt.title('t-SNE colored by safety_score')
add_watermark(fig)
plt.savefig(f'{fig_dir}tsne.png')
plt.close()

np.save(f"{processed_data_path}tsne_coords.npy", tsne_coords)
print("Saved tsne_coords.npy")
